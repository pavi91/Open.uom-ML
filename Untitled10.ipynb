# %% [markdown]
# <a href="https://colab.research.google.com/github/JMBuddhika/Open.uom-ML/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')

# Specify the file path
file_path = '/content/drive/MyDrive/UOM/Main.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path, delimiter='\t', encoding='utf-16')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#                                      Unnamed: 0  \
# 0  Dinuka Kannangara   - University of Kelaniya
# 1  Mr. Malinda Herath  - University of Kelaniya
# 2                                          Me !
# 3                                     RANKESH !
# 4                     IDHU THERIYAMA POACHE !!!
#
#                      Email address       1.1 Computational Thinking  \
# 0               dinukawk@kln.ac.lk                    Not completed
# 1               maher191@kln.ac.lk  Completed (achieved pass grade)
# 2  nadithidmoonasingha18@gmail.com  Completed (achieved pass grade)
# 3               rankeshd@gmail.com                    Not completed
# 4         kishankish2537@gmail.com                    Not completed
#
#             Unnamed: 3 1.2 Anatomy of a Software Application  \
# 0                  NaN                         Not completed
# 1  2022-03-13 08:17:28       Completed (achieved pass grade)
# 2  2023-09-01 23:42:11                         Not completed
# ...

# %%
df.tail()
# Out:
#               Unnamed: 0                 Email address  \
# 158869  ʜᴀʀɪɴᴅᴜ ꜱᴀɴᴅᴇᴇᴘᴀ  harindusandeepa123@gmail.com
# 158870    ꜱᴀᴊɪᴅᴇᴇɴ ꜱᴀᴊᴀʜ            123sajah@gmail.com
# 158871            사치니 사라        sachinisarah@gmail.com
# 158872        /컴퓨터공학과 아식         aashik96@gachon.ac.kr
# 158873     Thanju 탄주2k21     thanjuladinuk21@gmail.com
#
#              1.1 Computational Thinking           Unnamed: 3  \
# 158869  Completed (achieved pass grade)  2023-03-19 10:37:51
# 158870                    Not completed                  NaN
# 158871  Completed (achieved pass grade)  2022-06-28 11:41:51
# 158872                    Not completed                  NaN
# 158873                    Not completed                  NaN
#
#        1.2 Anatomy of a Software Application           Unnamed: 5  \
# 158869       Completed (achieved pass grade)  2023-03-19 11:05:56
# 158870                         Not completed                  NaN
# ...

# %%
# !git add .
# !git commit -m "Your commit message"
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
